# %%
import os
import random
import pickle
import plotly
import pandas
import sklearn

# %%
# load objects
if os.path.exists(os.path.abspath('./saved_music_dict.pickle')):
    with open('saved_music_dict.pickle', 'rb') as handle:
        saved_music_dict = pickle.load(handle)
        
if os.path.exists(os.path.abspath('./new_music_dict.pickle')):
    with open('new_music_dict.pickle', 'rb') as handle:
        new_music_dict = pickle.load(handle)

# %%
print(len(new_music_dict.keys()), len(saved_music_dict.keys()))
# Out:
# 4990 300

# %%
# saved_music_df = pandas.DataFrame(index=saved_music_dict.keys())
# saved_music_df['artist'] = saved_music_df.index.map(saved_music_dict)
# saved_music_df.head()`
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/pq/vgps88md18zcwpt3jxq_23dc0000gn/T/ipykernel_30988/1400336124.py in <module>
#       1 saved_music_df = pandas.DataFrame(index=saved_music_dict.keys())
# ----> 2 saved_music_df['artist'] = saved_music_df.index.map(saved_music_dict)['artist']
#       3 saved_music_df.head()
#
# ~/venv/dlrappeport/lib/python3.8/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4602         if is_scalar(key):
#    4603             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4604             return getitem(key)
#    4605
#    4606         if isinstance(key, slice):
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
saved_music_df = pandas.DataFrame(data=saved_music_dict).T
saved_music_df.head()
# Out:
#                                                                     album  \
# 5bFuHlXKw66Uu2cHKn5bf8  {'album_type': 'single', 'artists': [{'externa...
# 6rx7O4uhp7mPfNvq9FCkos  {'album_type': 'album', 'artists': [{'external...
# 2Xgwpj62TZGituPLdHk6vk  {'album_type': 'compilation', 'artists': [{'ex...
# 0oGnHTdtPTgTqTJVeWw0EU  {'album_type': 'album', 'artists': [{'external...
# 5yfHDmZHjMw2gLjbghG90V  {'album_type': 'single', 'artists': [{'externa...
#
#                                                                   artists  \
# 5bFuHlXKw66Uu2cHKn5bf8  [{'external_urls': {'spotify': 'https://open.s...
# 6rx7O4uhp7mPfNvq9FCkos  [{'external_urls': {'spotify': 'https://open.s...
# 2Xgwpj62TZGituPLdHk6vk  [{'external_urls': {'spotify': 'https://open.s...
# 0oGnHTdtPTgTqTJVeWw0EU  [{'external_urls': {'spotify': 'https://open.s...
# 5yfHDmZHjMw2gLjbghG90V  [{'external_urls': {'spotify': 'https://open.s...
#
# ...

# %%
saved_music_df.audio_features.apply(pandas.Series).head()
# Out:
#                         danceability  energy  key  loudness  mode  \
# 5bFuHlXKw66Uu2cHKn5bf8         0.618   0.758    8    -7.996     1
# 6rx7O4uhp7mPfNvq9FCkos         0.704   0.701    6    -7.104     1
# 2Xgwpj62TZGituPLdHk6vk         0.321   0.898    9    -7.188     1
# 0oGnHTdtPTgTqTJVeWw0EU         0.756   0.553    1    -5.712     1
# 5yfHDmZHjMw2gLjbghG90V         0.849   0.558   10    -9.230     0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 5bFuHlXKw66Uu2cHKn5bf8       0.0336        0.0087           0.10200    0.1470
# 6rx7O4uhp7mPfNvq9FCkos       0.0451        0.0110           0.86500    0.0668
# 2Xgwpj62TZGituPLdHk6vk       0.0633        0.3210           0.71700    0.9010
# 0oGnHTdtPTgTqTJVeWw0EU       0.0488        0.1040           0.00926    0.5120
# 5yfHDmZHjMw2gLjbghG90V       0.0437        0.0498           0.00634    0.1190
#
#                         valence    tempo            type  \
# ...

# %%
saved_music_df.artists.apply(pandas.Series)[0].apply(pandas.Series).head()
# Out:
#                                                             external_urls  \
# 5bFuHlXKw66Uu2cHKn5bf8  {'spotify': 'https://open.spotify.com/artist/6...
# 6rx7O4uhp7mPfNvq9FCkos  {'spotify': 'https://open.spotify.com/artist/0...
# 2Xgwpj62TZGituPLdHk6vk  {'spotify': 'https://open.spotify.com/artist/7...
# 0oGnHTdtPTgTqTJVeWw0EU  {'spotify': 'https://open.spotify.com/artist/5...
# 5yfHDmZHjMw2gLjbghG90V  {'spotify': 'https://open.spotify.com/artist/5...
#
#                                                                      href  \
# 5bFuHlXKw66Uu2cHKn5bf8  https://api.spotify.com/v1/artists/67qogtRNI0G...
# 6rx7O4uhp7mPfNvq9FCkos  https://api.spotify.com/v1/artists/0uRdK8gy7fX...
# 2Xgwpj62TZGituPLdHk6vk  https://api.spotify.com/v1/artists/7cyGjvBzuLN...
# 0oGnHTdtPTgTqTJVeWw0EU  https://api.spotify.com/v1/artists/5tkITWzssc9...
# 5yfHDmZHjMw2gLjbghG90V  https://api.spotify.com/v1/artists/5vfEaoOBcK0...
#
#                                             id                    name  \
# ...

# %%
saved_music_dict[random.choice(list(saved_music_dict.keys()))]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/63aP18bg2ABSOqSNQcAMNy'},
#     'href': 'https://api.spotify.com/v1/artists/63aP18bg2ABSOqSNQcAMNy',
#     'id': '63aP18bg2ABSOqSNQcAMNy',
#     'name': 'Allen Toussaint',
#     'type': 'artist',
#     'uri': 'spotify:artist:63aP18bg2ABSOqSNQcAMNy'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
# ...
