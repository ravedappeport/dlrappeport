# %%
import yaml
import spotipy
import urllib as url
from spotipy.oauth2 import SpotifyOAuth

# %%
creds = yaml.load(open('/Users/daverappeport/.spotify/creds.yml','r'), Loader=yaml.FullLoader)
redirect_url="http://localhost:9001/callback"
scope = ["user-library-read", "playlist-modify-private","playlist-modify-public"]

# %%
auth_manager=SpotifyOAuth(client_id=creds.get('client_id'), client_secret=creds.get('client_secret'), redirect_uri=redirect_url, scope=scope)
sp=spotipy.Spotify(auth_manager=auth_manager)

# %%
results = sp.current_user_saved_tracks()

# %%
results.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results.get('items')[0].get('track').keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
user=sp.current_user()

# %%
for plist in sp.user_playlists(user=user['id']).get('items'):
    print(plist.get('name'))
# Out:
# My Peloton Music by RaveDapeport
# Golden Hour
# Rapp Haus
# Ghost Town
# Asian Dinner
# Vibes
# Cruise
# The Long and Winding Road
# good shit
# Workout
# Starred
# Gimme Some More
# Liked from Radio
# GDTG

# %%
running_seeds_url="https://open.spotify.com/playlist/5NrLk0qUyICYEG8cZWK7SL"
res_playlist_id=url.parse.urlparse(running_seeds_url).path.split('/')[2]

# %%
running_recs_url="https://open.spotify.com/playlist/3Elnf5eDmqXA9dC52Dr9UJ"
rec_playlist_id=url.parse.urlparse(running_recs_url).path.split('/')[2]

# %%
seed_tracks = sp.playlist_items(playlist_id=res_playlist_id)

# %%
seed_track_ids = [track.get('track').get('id') for track in seed_tracks.get('items')]

# %%
seed_track_ids

# %%
res = sp.recommendations(seed_tracks=seed_track_ids)
len(res.get('tracks'))

# %%
rec_track_ids = [track.get('id') for track in res.get('tracks')]

# %%
sp.playlist_replace_items(playlist_id=rec_playlist_id, items=rec_track_ids)

# %% [markdown]
# ### if you need to clear the playlist
# sp.playlist_remove_all_occurrences_of_items(
#     playlist_id=rec_playlist_id,
#     items=[track.get('track').get('id') for track in sp.playlist_items(playlist_id=rec_playlist_id).get('items')]
# )

# %%
# audio features
sp.audio_features(tracks=rec_track_ids)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/pq/vgps88md18zcwpt3jxq_23dc0000gn/T/ipykernel_17844/563919959.py in <module>
#       1 # audio features
# ----> 2 sp.audio_features(tracks=rec_track_ids)
#
# NameError: name 'rec_track_ids' is not defined

# %%
res = sp.current_user_saved_tracks(limit=50)

# %%
res.get('items')[0].get('track')
new_music = []

for item in res.get('items'):
    item = item.get('track')
    print(item.get('name') + ';' + item.get('artists')[0].get('name'))
    
    seed_id = item.get('id')
    # print(seed_id)
    
    
    recs = sp.recommendations(seed_tracks=[seed_id])
    
    for track in recs.get('tracks'):
        new_music.append(track)
# Out:
# Moonwalk Away;GoldFish
# Hey Jude;The Overton Berry Trio
# Arcadia;Goose
# Hot Hands;Darius
# Roll Back - Single Mix;George FitzGerald
# Electrify Me;ZHU
# NUMB;Hayden James
# Lady Madonna;Fats Domino
# Blueberry Hill;Fats Domino
# Marissa;Mike Gordon
# I Know You Rider - Live;The National
# Mahalla;Carolina Chocolate Drops
# Go Go Round This World!;Fishmans
# Hook;Blues Traveler
# Waiting All Night - Live;Phish
# The Wilhelm Scream;The Bamboos
# Bees;Caribou
# Rudie Can't Fail - Remastered;The Clash
# Kiss With A Fist;Florence + The Machine
# Antigone - Yotto Remix;Joris Voorn
# Águas De Março;Antônio Carlos Jobim
# I Like It;DeBarge
# Cleopatra;The Lumineers
# Kick It to Me;Sammy Rae & The Friends
# Rocky Raccoon;Scary Pockets
# Say My Name;Matvey Emerson
# Wash My Soul;Chris Malinchak
# In The Air Tonight - Croatia Squad Remix;Nora En Pure
# I Wanna Dance With Somebody (Who Loves Me);Nora Van Elken
# I'm On Fire;ConKi
# Everybody’s Gotta Live;Love
# You're the One;The Black Keys
# The Choice Is Yours (Revisited);Black Sheep
# Expensive Shit;Fela Kuti
# A World So Full of Love;Shakey Graves
# THAT'S THAT;MF DOOM
# Riot!;Earl Sweatshirt
# Sorry You're Sick;Ted Hawkins
# Opposite People;Fela Kuti
# Poor Man's Shangri-La;Ry Cooder
# Only the Wild Ones;Dispatch
# I Was Dancing In The Lesbian Bar;Jonathan Richman
# The Guns of Brixton - Remastered;The Clash
# The Impression That I Get;The Mighty Mighty Bosstones
# Problems;Don Diablo
# You've Done Enough;Gorgon City
# Conga Rock;Diplo
# Some Day I Will;Barry Can't Swim
# Damn It Feels Good to Be a Gangsta;Geto Boys
# I'd Rather Dance With You;Kings of Convenience

# %%
print(len(new_music))

new_music[0]
# Out:
# 1000
# {'album': {'album_type': 'SINGLE',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LFGVkNRmXz8jIkyPjaGNL'},
#     'href': 'https://api.spotify.com/v1/artists/1LFGVkNRmXz8jIkyPjaGNL',
#     'id': '1LFGVkNRmXz8jIkyPjaGNL',
#     'name': 'De Hofnar',
#     'type': 'artist',
#     'uri': 'spotify:artist:1LFGVkNRmXz8jIkyPjaGNL'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1ZA146RN2Cu9HCpDk8PpQK'},
#   'href': 'https://api.spotify.com/v1/albums/1ZA146RN2Cu9HCpDk8PpQK',
#   'id': '1ZA146RN2Cu9HCpDk8PpQK',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b1bb336915157eb2f71e869f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b1bb336915157eb2f71e869f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b1bb336915157eb2f71e869f',
#     'width': 64}],
#   'name': 'Zonnestraal',
#   'release_date': '2013',
#   'release_date_precision': 'year',
#   'total_tracks': 3,
#   'type': 'album',
#   'uri': 'spotify:album:1ZA146RN2Cu9HCpDk8PpQK'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LFGVkNRmXz8jIkyPjaGNL'},
#    'href': 'https://api.spotify.com/v1/artists/1LFGVkNRmXz8jIkyPjaGNL',
#    'id': '1LFGVkNRmXz8jIkyPjaGNL',
#    'name': 'De Hofnar',
#    'type': 'artist',
#    'uri': 'spotify:artist:1LFGVkNRmXz8jIkyPjaGNL'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 1,
#  'duration_ms': 401008,
#  'explicit': False,
#  'external_ids': {'isrc': 'FR6V82085805'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/5CeTuypSIJIOq0nUs4uhBh'},
#  'href': 'https://api.spotify.com/v1/tracks/5CeTuypSIJIOq0nUs4uhBh',
#  'id': '5CeTuypSIJIOq0nUs4uhBh',
#  'is_local': False,
#  'name': 'Vogelvlucht',
#  'popularity': 47,
#  'preview_url': 'https://p.scdn.co/mp3-preview/9b8853240a83da6bf4aa483a163464148b2bc659?cid=cdd87adb3cbc4eb481fb88a98505517b',
#  'track_number': 2,
#  'type': 'track',
#  'uri': 'spotify:track:5CeTuypSIJIOq0nUs4uhBh'}
